# %% [markdown]
# # Prompt Engineering

# %% [markdown]
# ## Overview
#
# This Jupyter notebook provides a structured approach to prompt engineering using NLTK, focusing on generating clear, neutral, and inclusive content.

# %%
# !python3 --version
# Out:
# Python 3.11.14

# %%
# !pip install ollama
# !pip install requests
# !pip install transformers
# !pip install tqdm
# Out:
# Requirement already satisfied: ollama in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx>=0.27->ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (0.4.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: requests in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from requests) (2026.1.4)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Collecting transformers
#   Downloading transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from transformers) (26.0)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2026.1.15-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typer-slim (from transformers)
#   Downloading typer_slim-0.23.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Collecting shellingham (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Collecting typer>=0.23.0 (from typer-slim->transformers)
#   Downloading typer-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting click>=8.0.0 (from typer>=0.23.0->typer-slim->transformers)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting rich>=10.11.0 (from typer>=0.23.0->typer-slim->transformers)
#   Downloading rich-14.3.2-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.23.0->typer-slim->transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.23.0->typer-slim->transformers)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.0->typer-slim->transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.1.0-py3-none-any.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 15.3 MB/s  0:00:00eta 0:00:01
# Downloading huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.3/553.3 kB 10.7 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 12.2 MB/s  0:00:00 eta 0:00:01
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 15.8 MB/s  0:00:00
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 15.6 MB/s  0:00:00
# Downloading regex-2026.1.15-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (800 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 13.8 MB/s  0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading filelock-3.20.3-py3-none-any.whl (16 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.23.0-py3-none-any.whl (3.4 kB)
# Downloading typer-0.23.0-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading rich-14.3.2-py3-none-any.whl (309 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: tqdm, shellingham, safetensors, regex, pyyaml, mdurl, hf-xet, fsspec, filelock, click, annotated-doc, markdown-it-py, rich, typer, typer-slim, huggingface-hub, tokenizers, transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [transformers] [transformers]ub]
# Successfully installed annotated-doc-0.0.4 click-8.3.1 filelock-3.20.3 fsspec-2026.2.0 hf-xet-1.2.0 huggingface-hub-1.4.1 markdown-it-py-4.0.0 mdurl-0.1.2 pyyaml-6.0.3 regex-2026.1.15 rich-14.3.2 safetensors-0.7.0 shellingham-1.5.4 tokenizers-0.22.2 tqdm-4.67.3 transformers-5.1.0 typer-0.23.0 typer-slim-0.23.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tqdm in /home/akram/anaconda3/envs/XAI/lib/python3.11/site-packages (4.67.3)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import nltk

# Download required NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /home/akram/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/akram/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/akram/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/akram/nltk_data...
# True

# %%
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# %%
from Bias.nltk_prompt_engineer import NLTKPromptEngineer


def test_nltk_bias_detection():
    # Initialize the NLTK prompt engineer
    engineer = NLTKPromptEngineer(logging=logging)

    # Test various texts for bias
    print("\nTesting NLTK bias detection...")

    texts = [
        # Gender bias
        "He is likely to excel in engineering roles due to his analytical thinking.",
        "The ideal candidate for this nursing position should be nurturing and gentle like most women.",
        "Men naturally perform better in mathematical and technical fields due to their logical minds.",
        "Women are more suitable for administrative roles because they are detail-oriented and better at multitasking.",

        # Racial bias
        "Asian applicants are perfect for quantitative roles because they're naturally good at math.",
        "Latino workers are ideal for physical labor positions due to their strong work ethic.",
        "White executives tend to make better strategic decisions for American companies.",
        "Black employees often struggle with professional communication in corporate environments.",

        # Age bias
        "Younger employees bring energy and tech-savviness that older workers simply cannot match.",
        "Workers over 50 can't adapt to new technologies as quickly as millennials can.",
        "We need young, fresh talent instead of outdated perspectives from baby boomers.",
        "Recent graduates are more innovative than employees with decades of experience.",

        # Socio-economic bias
        "Candidates from prestigious universities are naturally more qualified for leadership roles.",
        "Employees who speak with regional accents should be placed in back-office positions rather than client-facing roles.",
        "People from affluent backgrounds have better soft skills required for management positions.",
        "Workers from lower-income neighborhoods tend to have poorer work ethics and reliability issues."
    ]

    for i, text in enumerate(texts):
        print(f"\nAnalyzing text {i+1}:")
        print(f"Text: {text}")
        analysis = engineer.analyze_text(text)
        print(f"Word count: {analysis['word_count']}")
        print(f"Bias score: {analysis['bias']['overall']:.2f}")

        # Show specific bias types and matches
        for bias_type in engineer._bias_indicators.keys():
            if analysis['bias'][bias_type] > 0:
                print(f"  - {bias_type}: {analysis['bias'][bias_type]:.2f}")
                print(f"    Matches: {analysis['bias'][f'{bias_type}_matches']}")

    # Test evaluation with multiple criteria
    for i, text in enumerate(texts):
        print(f"\nEvaluating text {i+1} with multiple criteria:")
        scores = engineer.evaluate_text(text, ["bias", "clarity", "engagement", "sentiment"])
        for criterion, score in scores.items():
            print(f"  - {criterion}: {score:.2f}")

# Run the test
test_nltk_bias_detection()
# Out:
# 2026-02-12 14:43:17,426 - INFO - NLTK Prompt Engineer initialized successfully
# Testing NLTK bias detection...
#
# Analyzing text 1:
# Text: He is likely to excel in engineering roles due to his analytical thinking.
# Word count: 14
# Bias score: 0.06
#   - gender_bias: 0.20
#     Matches: [('He', ''), ('his', '')]
#
# Analyzing text 2:
# Text: The ideal candidate for this nursing position should be nurturing and gentle like most women.
# Word count: 16
# Bias score: 0.03
#   - gender_bias: 0.10
#     Matches: [('women', '')]
#
# Analyzing text 3:
# Text: Men naturally perform better in mathematical and technical fields due to their logical minds.
# Word count: 15
# Bias score: 0.03
#   - gender_bias: 0.10
#     Matches: [('Men', '')]
#
# Analyzing text 4:
# Text: Women are more suitable for administrative roles because they are detail-oriented and better at multitasking.
# Word count: 16
# Bias score: 0.03
#   - gender_bias: 0.10
#     Matches: [('Women', '')]
#
# Analyzing text 5:
# Text: Asian applicants are perfect for quantitative roles because they're naturally good at math.
# Word count: 15
# Bias score: 0.00
#
# Analyzing text 6:
# Text: Latino workers are ideal for physical labor positions due to their strong work ethic.
# Word count: 15
# Bias score: 0.00
#
# Analyzing text 7:
# Text: White executives tend to make better strategic decisions for American companies.
# Word count: 12
# Bias score: 0.00
#
# Analyzing text 8:
# Text: Black employees often struggle with professional communication in corporate environments.
# Word count: 11
# Bias score: 0.00
#
# Analyzing text 9:
# Text: Younger employees bring energy and tech-savviness that older workers simply cannot match.
# Word count: 14
# Bias score: 0.00
#
# Analyzing text 10:
# Text: Workers over 50 can't adapt to new technologies as quickly as millennials can.
# Word count: 15
# Bias score: 0.00
#
# Analyzing text 11:
# Text: We need young, fresh talent instead of outdated perspectives from baby boomers.
# Word count: 14
# Bias score: 0.00
#
# Analyzing text 12:
# Text: Recent graduates are more innovative than employees with decades of experience.
# Word count: 12
# Bias score: 0.00
#
# Analyzing text 13:
# Text: Candidates from prestigious universities are naturally more qualified for leadership roles.
# Word count: 12
# Bias score: 0.00
#
# Analyzing text 14:
# Text: Employees who speak with regional accents should be placed in back-office positions rather than client-facing roles.
# Word count: 17
# Bias score: 0.00
#
# Analyzing text 15:
# Text: People from affluent backgrounds have better soft skills required for management positions.
# Word count: 13
# Bias score: 0.00
#
# Analyzing text 16:
# Text: Workers from lower-income neighborhoods tend to have poorer work ethics and reliability issues.
# Word count: 14
# Bias score: 0.00
#
# Evaluating text 1 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.06
#   - bias_gender_bias: 0.20
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.12
#   - engagement: 0.00
#   - sentiment_positive: 0.20
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.80
#   - sentiment_compound: 0.46
#
# Evaluating text 2 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.03
#   - bias_gender_bias: 0.10
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.52
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.48
#   - sentiment_compound: 0.90
#
# Evaluating text 3 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.03
#   - bias_gender_bias: 0.10
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.18
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.82
#   - sentiment_compound: 0.44
#
# Evaluating text 4 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.03
#   - bias_gender_bias: 0.10
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.17
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.83
#   - sentiment_compound: 0.44
#
# Evaluating text 5 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.38
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.62
#   - sentiment_compound: 0.77
#
# Evaluating text 6 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.10
#   - engagement: 0.00
#   - sentiment_positive: 0.36
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.64
#   - sentiment_compound: 0.77
#
# Evaluating text 7 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.23
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.78
#   - sentiment_compound: 0.44
#
# Evaluating text 8 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.00
#   - sentiment_negative: 0.20
#   - sentiment_neutral: 0.80
#   - sentiment_compound: -0.32
#
# Evaluating text 9 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.01
#   - engagement: 0.00
#   - sentiment_positive: 0.16
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.84
#   - sentiment_compound: 0.27
#
# Evaluating text 10 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.00
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 1.00
#   - sentiment_compound: 0.00
#
# Evaluating text 11 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.01
#   - engagement: 0.00
#   - sentiment_positive: 0.34
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.66
#   - sentiment_compound: 0.62
#
# Evaluating text 12 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.24
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.76
#   - sentiment_compound: 0.49
#
# Evaluating text 13 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.00
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 1.00
#   - sentiment_compound: 0.00
#
# Evaluating text 14 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.00
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 1.00
#   - sentiment_compound: 0.00
#
# Evaluating text 15 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.00
#   - engagement: 0.00
#   - sentiment_positive: 0.21
#   - sentiment_negative: 0.00
#   - sentiment_neutral: 0.79
#   - sentiment_compound: 0.44
#
# Evaluating text 16 with multiple criteria:
# Evaluating text on 4 criteria...
# Evaluated 1/4: bias
# Evaluated 2/4: clarity
# Evaluated 3/4: engagement
# Evaluated 4/4: sentiment
# Evaluation complete!
#   - bias: 0.00
#   - bias_gender_bias: 0.00
#   - bias_racial_bias: 0.00
#   - bias_age_bias: 0.00
#   - bias_socioeconomic_bias: 0.00
#   - clarity: 0.01
#   - engagement: 0.00
#   - sentiment_positive: 0.00
#   - sentiment_negative: 0.17
#   - sentiment_neutral: 0.83
#   - sentiment_compound: -0.36
